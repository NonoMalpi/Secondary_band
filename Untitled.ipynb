# %%
from aux_funcs import *

# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pickle.load(open('df', 'rb'))

# %%
option = american_option(24, 1000, 0.23, '2017-01-20 00:00:00', df)

# %%
option.plot_real_predicted_values()
